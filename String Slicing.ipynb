# %%
7th

# %% [markdown]
# String in Python

# %%
st = 'hellopython'
st
# Out:
# 'hellopython'

# %%
st[0]
# Out:
# 'h'

# %%
st[-1]
# Out:
# 'n'

# %%
st[10]
# Out:
# 'n'

# %%
st[6]
# Out:
# 'y'

# %% [markdown]
# Slicing in String

# %%
st
# Out:
# 'hellopython'

# %%
st[:]
# Out:
# 'hellopython'

# %%
st[5:10]
# Out:
# 'pytho'

# %%
st[5:11]
# Out:
# 'python'

# %%
st[0:5]
# Out:
# 'hello'

# %%
st1='fine'
st1
# Out:
# 'fine'

# %%
'd'+st1[1:]
# Out:
# 'dine'

# %%
's'+st1[1:]
# Out:
# 'sine'

# %%
'alex'+'blur'+'cat'
# Out:
# 'alexblurcat'

# %%
st2='nareshit'

# %%
st2[
    :]
# Out:
# 'nareshit'

# %%
print(st2[:])
# Out:
# nareshit

# %%
st2[-5:-2]
# Out:
# 'esh'

# %%
st2[::-1]
# Out:
# 'tihseran'
