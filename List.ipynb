# %%
l = []
l
# Out:
# []

# %%
l1 = list()
l1
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
len(l1)
# Out:
# 0

# %%
l.append(10)
l.append(20)
l.append(30)
l
# Out:
# [10, 10, 10, 10, 10, 20, 30, 10, 20, 30]

# %%
l.remove(10)
l.remove(20)
l.remove(30)
l
# Out:
# [10, 10, 10, 10]

# %%
l
# Out:
# [10, 10, 10, 10]

# %%
l1.append(10)

# %%
l1
# Out:
# [10, 10]

# %%
l1.append(20)
l1
# Out:
# [10, 10, 20, 20]

# %%
l1.append(30)

# %%
l1
# Out:
# [10, 10, 20, 20, 30]

# %%
l1.append(1.2)
l1.append('nit')
l1.append(True)
l1.append(1+2j)
l1.append(10)

# %%
l1
# Out:
# [10,
#  10,
#  20,
#  20,
#  30,
#  1.2,
#  'nit',
#  True,
#  (1+2j),
#  10,
#  1.2,
#  'nit',
#  True,
#  (1+2j),
#  10]

# %%
l1.append(20)

# %%
l1
# Out:
# [10,
#  10,
#  20,
#  20,
#  30,
#  1.2,
#  'nit',
#  True,
#  (1+2j),
#  10,
#  1.2,
#  'nit',
#  True,
#  (1+2j),
#  10,
#  20,
#  20]

# %%
print(len(l))
print(l1)
# Out:
# 4
# [10, 10, 20, 20, 30, 1.2, 'nit', True, (1+2j), 10, 1.2, 'nit', True, (1+2j), 10, 20, 20]

# %%
print(id(l))
print(id(l1))
# Out:
# 133888296625600
# 133888295539968

# %%
l1.append([1,2,3])

# %%
l1
# Out:
# [10,
#  10,
#  20,
#  20,
#  30,
#  1.2,
#  'nit',
#  True,
#  (1+2j),
#  10,
#  1.2,
#  'nit',
#  True,
#  (1+2j),
#  10,
#  20,
#  20,
#  [1, 2, 3],
#  [1, 2, 3]]

# %%
print(type(l1))
print(type(l1))
# Out:
# <class 'list'>
# <class 'list'>

# %%
l
# Out:
# [10, 10, 10, 10]

# %%
l2=l1.copy()

# %%
l2
# Out:
# [10,
#  10,
#  20,
#  20,
#  30,
#  1.2,
#  'nit',
#  True,
#  (1+2j),
#  10,
#  1.2,
#  'nit',
#  True,
#  (1+2j),
#  10,
#  20,
#  20,
#  [1, 2, 3],
#  [1, 2, 3]]

# %%
id(l1)==id(l2)
# Out:
# False

# %%
l2.clear()

# %%
l2
# Out:
# []

# %%
del l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-770718939.py in <cell line: 0>()
# ----> 1 del l2
#
# NameError: name 'l2' is not defined

# %%
print(l)
print(l2)
# Out:
# [10, 10, 10, 10]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1874953107.py in <cell line: 0>()
#       1 print(l)
# ----> 2 print(l2)
#
# NameError: name 'l2' is not defined

# %%
l1[:]
# Out:
# [10,
#  10,
#  20,
#  20,
#  30,
#  1.2,
#  'nit',
#  True,
#  (1+2j),
#  10,
#  1.2,
#  'nit',
#  True,
#  (1+2j),
#  10,
#  20,
#  20,
#  [1, 2, 3],
#  [1, 2, 3]]

# %%
l1[1:7]
# Out:
# [10, 20, 20, 30, 1.2, 'nit']

# %%
l1[0:8:2]
# Out:
# [10, 20, 30, 'nit']

# %%
l1[::1]
# Out:
# [10,
#  10,
#  20,
#  20,
#  30,
#  1.2,
#  'nit',
#  True,
#  (1+2j),
#  10,
#  1.2,
#  'nit',
#  True,
#  (1+2j),
#  10,
#  20,
#  20,
#  [1, 2, 3],
#  [1, 2, 3]]

# %%
l1[::-3]
# Out:
# [[1, 2, 3], 20, True, 10, 'nit', 20, 10]
