# %%
python  identifer = values

# %% [markdown]
# ## Python identifier = values #

# %%
i =3
i
# Out:
# 3

# %%
type(i)
# Out:
# int

# %%
i1 =300
i1
# Out:
# 300

# %%
type(i1)
# Out:
# int

# %%
petrol = 110.5
petrol
# Out:
# 110.5

# %%
f1=2e0
f1
# Out:
# 2.0

# %%
f1=2e1
f1
# Out:
# 20.0

# %%
f2=23e2
f2
# Out:
# 2300.0

# %%
f6=2.4e3
f6
# Out:
# 2400.0

# %%
type(f6)
# Out:
# float

# %% [markdown]
# # String#

# %%
s = 'nit'
s
# Out:
# 'nit'

# %%
s1 = "nit tech"
s1
# Out:
# 'nit tech'

# %%
s3 = '''nit
     technology'''
s3
# Out:
# 'nit\n     technology'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import sys
sys.version
# Out:
# '3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]'

# %%
a = 5
a
# Out:
# 5

# %%
id(a)
# Out:
# 10757864

# %% [markdown]
# In Python an identifier is a name given to entities such as variables, functions,classes,modules,or any other object in a program.It serves to uniquely identify these entities and allows you to refer to
#
# them within your code

# %% [markdown]
#  Value --> integer value | int data types
#
# float value | float data types
#
# string value | string data types
#
#
# complex value | complex data types
#
#
#
# boolean value | boolean data types

# %% [markdown]
# function() --- end with()

# %% [markdown]
# id()---> function

# %% [markdown]
# VARIABLE -- does not define with ()
#
#
# FUNCTION --  define with ()

# %%
 a =5
 a
# Out:
# 5

# %%
id(a)
# Out:
# 10757864

# %%
a = 6
a
# Out:
# 6

# %%
id(a)
# Out:
# 10757896

# %% [markdown]
# Python  Data Types have two types
# -------------------------------------------------------
#
#
#
#    Primiitive
#    Float
#
#    Integer
#
#    String
#
#    Bolean
#
# -------------------------------------------------------
#    USer-Defined
#
#    Stack
#
#
#    Queue
#
#    LinkedList
#
#    Tree

# %%
b = True
b
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
b1 = False
b1
# Out:
# False

# %%
True+False
# Out:
# 1

# %%
True-False
# Out:
# 1

# %%
True*True-False+False*True
# Out:
# 1

# %%
False*True
# Out:
# 0

# %%
False/True
# Out:
# 0.0

# %%
False//True
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2794436645.py in <cell line: 0>()
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %% [markdown]
# complex - a + bj
#
#
# a - real part &    b - imaainary part & j - square root of -1

# %%
c = 1+2j
c
# Out:
# (1+2j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 1.0

# %%
c.imag
# Out:
# 2.0

# %%
c
# Out:
# (1+2j)

# %%
d = 2+3j
d
# Out:
# (2+3j)

# %%
print(c)
print(d)
# Out:
# (1+2j)
# (2+3j)

# %%
c+d
# Out:
# (3+5j)

# %% [markdown]
# Type Cast from other DataType to integer

# %%
int(3.4)
# Out:
# 3

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3170945453.py in <cell line: 0>()
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1854362543.py in <cell line: 0>()
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
float(34)
# Out:
# 34.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('10')
# Out:
# 10.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3331339187.py in <cell line: 0>()
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2718724457.py in <cell line: 0>()
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# #Type CAST FROM OTHER DATATYPE TO BOOL

# %%
bool(56)
# Out:
# True

# %%
bool(5.6)
# Out:
# True

# %%
bool('nit')
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(1+2j)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %% [markdown]
# TYPE CAST FROM OTHER DATATYPE TO STRING

# %%
str(10)
# Out:
# '10'

# %%
str(10.10)
# Out:
# '10.1'

# %%
str(10.101)
# Out:
# '10.101'

# %%
str(True)
# Out:
# 'True'

# %%
int(True)
# Out:
# 1

# %%
str('False')
# Out:
# 'False'

# %%
int(False)
# Out:
# 0

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %% [markdown]
# TYPE CAST FROM OTHER DATATYPE TO COMPLEX

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3089141196.py in <cell line: 0>()
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(1.2,1.3)
# Out:
# (1.2+1.3j)

# %%
complex(1,5.6)
# Out:
# (1+5.6j)

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex(False,False)
# Out:
# 0j

# %%
complex('a','b')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-571364342.py in <cell line: 0>()
# ----> 1 complex('a','b')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2995795384.py in <cell line: 0>()
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string
