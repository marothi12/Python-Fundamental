# %% [markdown]
# Arithematic  Operator

# %%
x1 , y1 = 10,5
x1,y1
# Out:
# (10, 5)

# %%
x1
# Out:
# 10

# %%
y1
# Out:
# 5

# %%
x1+y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1
# Out:
# 0

# %%
x1**y1
# Out:
# 100000

# %%
x2 =3
y2 = 2
x2 ** y2
# Out:
# 9

# %% [markdown]
# Assignment operator

# %%
 x = 2

# %%
x==x
# Out:
# True

# %%
x= x  + 2
x
# Out:
# 4

# %%
x += 2
x
# Out:
# 6

# %%
x+=2
x
# Out:
# 8

# %%
x -=2
x
# Out:
# 6

# %%
x //= 2
x
# Out:
# 3

# %% [markdown]
# Relational Operator

# %% [markdown]
# we are using this operator for comparing

# %%
a = 5
b= 6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
# a = b we cannot  use = operator that means it is assigning #

# %%
a== b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
# hear if i change b = 6 #
b =5

# %%
a==b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
a < b
# Out:
# False

# %% [markdown]
# Logical Operator

# %%
a = 5
b = 4

# %%
a < 8 and b < 5 #refer to the truth table
# Out:
# True

# %%
a < 8 and b < 2
# Out:
# False

# %%
a > 8 and  b < 2
# Out:
# False

# %%
a < 8 or b < 2
# Out:
# True

# %%
a > 8 or b< 2
# Out:
# False

# %%
x = False
x
# Out:
# False

# %%
not x # you can reverse the operation
# Out:
# True

# %%
not x

# %%
x = not x
x
# Out:
# True

# %%
not x
# Out:
# False

# %% [markdown]
# Unary operator
# * unary mean 1 || binary means 2
# * Here we areapplying unary minus operator(-) on the operand n, the value of m becomes -7 ,which indicates it as a negative value.

# %%
n = 7
n
# Out:
# 7

# %%
m = -(n)
m
# Out:
# -7

# %%
n
# Out:
# 7
